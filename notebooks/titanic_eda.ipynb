# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Selection and Filtering

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[["Age", "Sex", "Survived"]]
# Out:
#       Age     Sex  Survived
# 0    22.0    male         0
# 1    38.0  female         1
# 2    26.0  female         1
# 3    35.0  female         1
# 4    35.0    male         0
# ..    ...     ...       ...
# 886  27.0    male         0
# 887  19.0  female         1
# 888   NaN  female         0
# 889  26.0    male         1
# 890  32.0    male         0
#
# [891 rows x 3 columns]

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df[df["Sex"] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Survived"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[
    (df["Sex"] == "female") &
    (df["Age"] < 30) 
]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[
    (df["Age"] > 30),
    ["Age", "Sex", "Pclass", "Survived"]
]
# Out:
#       Age     Sex  Pclass  Survived
# 1    38.0  female       1         1
# 3    35.0  female       1         1
# 4    35.0    male       3         0
# 6    54.0    male       1         0
# 11   58.0  female       1         1
# ..    ...     ...     ...       ...
# 873  47.0    male       3         0
# 879  56.0  female       1         1
# 881  33.0    male       3         0
# 885  39.0  female       3         0
# 890  32.0    male       3         0
#
# [305 rows x 4 columns]

# %%
df.iloc[:10, :5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# ...

# %%
df.loc[
    (df["Sex"] == "female") & (df["Age"] < 29),
    ["Name", "Survived"]
]
# Out:
#                                                   Name  Survived
# 2                               Heikkinen, Miss. Laina         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)         1
# 10                     Sandstrom, Miss. Marguerite Rut         1
# 14                Vestrom, Miss. Hulda Amanda Adolfina         0
# ..                                                 ...       ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)         1
# 875                   Najib, Miss. Adele Kiamie "Jane"         1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)         1
# 882                       Dahlberg, Miss. Gerda Ulrika         0
# 887                       Graham, Miss. Margaret Edith         1
#
# [140 rows x 2 columns]

# %%
df.iloc[:100].loc[
    lambda x: x["Sex"] == "female"
]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 14           15         0       3
# 15           16         1       2
# 18           19         0       3
# 19           20         1       3
# 22           23         1       3
# 24           25         0       3
# 25           26         1       3
# 28           29         1       3
# 31           32         1       1
# 32           33         1       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 43           44         1       2
# 44           45         1       3
# 47           48         1       3
# 49           50         0       3
# 52           53         1       1
# ...

# %%
df.loc[
    (df["Sex"] == "female") & (df["Age"] < 29),
    ["Name", "Age", "Survived"]
].iloc[:10]
# Out:
#                                                  Name   Age  Survived
# 2                              Heikkinen, Miss. Laina  26.0         1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0         1
# 10                    Sandstrom, Miss. Marguerite Rut   4.0         1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  14.0         0
# 22                        McGowan, Miss. Anna "Annie"  15.0         1
# 24                      Palsson, Miss. Torborg Danira   8.0         0
# 38                 Vander Planke, Miss. Augusta Maria  18.0         0
# 39                        Nicola-Yarred, Miss. Jamila  14.0         1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  27.0         0

# %% [markdown]
# ## Missing Values

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isna().mean() * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
missing = pd.DataFrame({
    "missing_count": df.isna().sum(),
    "missing_percent": df.isna().mean() * 100
})

missing
# Out:
#              missing_count  missing_percent
# PassengerId              0         0.000000
# Survived                 0         0.000000
# Pclass                   0         0.000000
# Name                     0         0.000000
# Sex                      0         0.000000
# Age                    177        19.865320
# SibSp                    0         0.000000
# Parch                    0         0.000000
# Ticket                   0         0.000000
# Fare                     0         0.000000
# Cabin                  687        77.104377
# Embarked                 2         0.224467

# %%
df["Age"].isna().sum()
# Out:
# np.int64(177)

# %%
df["Cabin"].isna().sum()
# Out:
# np.int64(687)

# %%
df["Embarked"].isna().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ## Missing Values Analysis
#
# `Age` has 177 missing values, which is about 20% of the dataset.
# `Cabin` has 687 missing values, which is more than 75% of the dataset, so this column is heavily incomplete.
# `Embarked` has only 2 missing values, so the amount of missing data there is very small.
# All other columns are complete.
# to create more specified and complete , but missing values will need to be handled before more advanced analysis or modeling.

# %% [markdown]
# ## Survival Analysis

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df["Survived"].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby(["Sex", "Pclass"])["Survived"].mean()
# Out:
# Sex     Pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: Survived, dtype: float64

# %%
df.groupby("Survived")["Age"].mean()
# Out:
# Survived
# 0    30.626179
# 1    28.343690
# Name: Age, dtype: float64

# %%
df[df["Age"] < 18]["Survived"].mean()
# Out:
# np.float64(0.5398230088495575)

# %%
df.groupby("Survived")["Fare"].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
df.groupby(["Sex", "Pclass"])["Survived"].agg(["mean", "count"])
# Out:
#                    mean  count
# Sex    Pclass
# female 1       0.968085     94
#        2       0.921053     76
#        3       0.500000    144
# male   1       0.368852    122
#        2       0.157407    108
#        3       0.135447    347

# %% [markdown]
# ## Family Size Analysis

# %%
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1

# %%
df.groupby("FamilySize")["Survived"].agg(["mean", "count"])
# Out:
#                 mean  count
# FamilySize
# 1           0.303538    537
# 2           0.552795    161
# 3           0.578431    102
# 4           0.724138     29
# 5           0.200000     15
# 6           0.136364     22
# 7           0.333333     12
# 8           0.000000      6
# 11          0.000000      7

# %% [markdown]
# Passengers traveling in small families had higher survival rates than passengers traveling alone or in very large families.
# Among the observed family sizes, families of 4 had the highest survival rate.

# %% [markdown]
# ## Visualizations

# %%
df["Survived"].value_counts().plot(kind="bar")
plt.title("Survival Counts")
plt.xlabel("Survived")
plt.ylabel("Passengers")
plt.show()

# %%
df.groupby("Sex")["Survived"].mean().plot(kind="bar")
plt.title("Survival Rate by Sex")
plt.ylabel("Survival Rate")
plt.show()

# %%
df.groupby("Pclass")["Survived"].mean().plot(kind="bar")
plt.title("Survival Rate by Passenger Class")
plt.ylabel("Survival Rate")
plt.show()

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The analysis shows several clear patterns in Titanic passenger survival.
#
# Female passengers had a substantially higher survival rate than male passengers.
#
# First-class passengers had a higher survival rate than passengers in second and third class.
#
# Passengers traveling in small families generally had better survival rates than those traveling alone or in very large families. Among the observed family sizes, families of 4 had the highest survival rate.
#
# Children also showed a higher survival rate compared with adults.
#
# Passengers who survived paid higher fares on average, although fare is also related to passenger class.
